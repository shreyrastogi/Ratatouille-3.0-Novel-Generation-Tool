# %% [markdown]
# **Downloading, Installing & Importing Required Libraries**

# %%
import pandas as pd

# %% [markdown]
# **Mounting Google Drive for importing the Data Files which will be used in the Tokenization**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Defining Post Processing Methods**

# %% [markdown]
# **Method to Remove the unnecessary Spaces occuring in the instructions of the Novel Recipe**

# %%
def removeSpacesFromRecipeInstructions(df):
  recipeIns=list(df['Recipe Instructions'])
  finalIns=list()
  for eachIns in recipeIns:
    x=eachIns.strip()
    finalIns.append(x)
  df=df.drop(['Recipe Instructions'], axis=1)
  df['Recipe Instructions']=finalIns
  return df

# %% [markdown]
# **Method to Remove the unnecessary column occuring the csv File named "Unnamed: 0"**

# %%
def removeUnnamed0Column(df):
  df=df.drop(['Unnamed: 0'], axis=1)
  return df

# %% [markdown]
# **Method to Remove the unnecessary column occuring the csv File named "Unnamed: 0.1"**

# %%
def removeUnnamed01Column(df):
  df=df.drop(['Unnamed: 0.1'], axis=1)
  return df

# %% [markdown]
# **Method to Rename the columns of Final Dataframe which will contain Post Processed Novel Recipes**

# %%
def renameColumns(df):
  df.rename(columns = {'Recipe Titile':'title'}, inplace = True)
  df.rename(columns = {'Ingredient Phrases':'ingredients'}, inplace = True)
  df.rename(columns = {'Recipe Instructions':'instructions'}, inplace = True)
  return df

# %% [markdown]
# **Method to Assign Recipes IDs to each Novel Recipe, startId parameter of this method will store the starting ID from which you want to start assigning. By default, loop in this method runs for 10k iterations, means it will assign Ids from startId to next 10k recipes, change it according to your need.**

# %%
def assignRecipeIds(df,startId):
  recipesIds=[]
  for i in range(startId,startId+10000):
    currentRecipeId=str(i+1)
    recipesIds.append(currentRecipeId)
  df['Sno']=recipesIds
  df.set_index('Sno',inplace=True)
  return df

# %% [markdown]
# **Method to Remove the "Random Ingredients" column**

# %%
def removeRandomIngredientColumn(df):
  df=df.drop(['Random Ingredients'], axis=1)
  return df

# %% [markdown]
# **Steps of Splitting of CSV File Data into multiple parts**

# %%
df=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_13.csv')

# %%
df.shape
# Out:
# (3500, 5)

# %%
partOne=df.iloc[0:500,:]
partTwo=df.iloc[500:2500,:]
partThree=df.iloc[2500:,:]

# %%
partOne.shape
# Out:
# (500, 5)

# %%
partTwo.shape
# Out:
# (2000, 5)

# %%
partThree.shape
# Out:
# (1000, 5)

# %%
partOne.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/500_Niharika_13.1.csv')

# %%
partTwo.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/2000_Niharika_13.2.csv')

# %%
partThree.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/1000_Niharika_13.3.csv')

# %% [markdown]
# **Generation of Batches of Novel Recipes Start from here:**

# %% [markdown]
# **The 1st and 2nd batch are post Processed manually by the developing team, We have developed and used this notebook for post processing for all the remaining batches.**

# %% [markdown]
# **Prepairing 3rd batch of 10000 recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Adarsh Results/Adarsh_5_1000_Recipes.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Adarsh Results/Adarsh_8_4000_Recipes.csv')
df3=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_2_1500.csv')
df4=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_3_3500.csv')

# %%
df=pd.concat([df1,df2,df3,df4])

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0           0.0
# 1           1           1.0
# 2           2           2.0
# 3           3           3.0
# 4           4           4.0
#
#                                   Random Ingredients  \
# 0  green olive,bread,cranberry sauce,chile pepper...
# 1                         rosemary,red chili,saffron
# 2      venison roast,parmesan cheese,kielbasa,potato
# 3  parsley sprig,seasoning salt,plain nonfat yogu...
# 4  confectioner sugar,spaghetti,tomato paste,brus...
#
#                                 Recipe Titile  \
# 0                Spicy Chilli and Tomato Soup
# 1  Advieh - Persian Saffron Roast Spice Blend
# 2                             Irish Pot Roast
# 3                        Curried Rotini Pasta
# 4          Quick and Easy Chicken N' N' Pasta
#
#                                   Ingredient Phrases  \
# 0   8 slices bread | 1/3 cup red curry paste | 2 ...
# 1   5 tablespoons saffron, soaked in | 1/2 teaspo...
# 2   2 large potatoes | 3 lbs smoked baby back rib...
# 3   1 1/2 cups rotini pasta, dry and broken into ...
# 4   1 pound uncooked smoked chicken breast halves...
#
#                                  Recipe Instructions
# 0   Preheat the oven to 350 degrees f. Brush a 9x...
# 1   Grind or pound saffron into a powder with 1/2...
# 2   Cover whole pot with water and bring to boil ...
# 3   In large bowl, toss drained pasta with yogurt...
# 4   Combine the chicken, tomato paste, and confec...

# %%
df=removeUnnamed0Column(df)

# %%
df=removeUnnamed01Column(df)

# %%
df.head()
# Out:
#                                   Random Ingredients  \
# 0  dark turkey meat,tortilla,moroccan seasoning,c...
# 1  golden raisin,pepperjack cheese,ginger garlic ...
# 2          italian sausage,beef brisket,tomato juice
# 3             coriander powder,garam masala,cardamom
# 4  onion soup mix,beef,bell pepper,cheese tortell...
#
#                                        Recipe Titile  \
# 0  Moroccan Style Beef Wraps (21 Day Wonder Diet:...
# 1                            Crock Pot Welsh Rarebit
# 2                                       Easy Brisket
# 3                           Garam Masala Spice Blend
# 4                    Quick  Cheez  Chili Beef  Pasta
#
#                                   Ingredient Phrases  \
# 0   600 g dark turkey meat | 1 1/2 teaspoons curr...
# 1   6 -8 ounces boneless blade steak | 1/4 cup fr...
# 2   2 large italian sausage, or other ground beef...
# 3   1 1/2 teaspoons coriander powder | 1/2 teaspo...
# 4   1 lb beef | 12 ounces cheese tortellini, unco...
#
#                                  Recipe Instructions
# 0   Cook turkey over medium heat in a medium sauc...
# 1   Put the first 3 ingredients in the crockpot. ...
# 2   Preheat oven to 300 degrees f. Place brisket ...
# 3   Using an electric spice mill grind coriander ...
# 4   Cut beef into 1 thick slices. Place slices be...

# %%
df=removeSpacesFromRecipeInstructions(df)

# %%
df=assignRecipeIds(df,20000)

# %%
df.head()
# Out:
#                                       Random Ingredients  \
# Sno
# 20001  dark turkey meat,tortilla,moroccan seasoning,c...
# 20002  golden raisin,pepperjack cheese,ginger garlic ...
# 20003          italian sausage,beef brisket,tomato juice
# 20004             coriander powder,garam masala,cardamom
# 20005  onion soup mix,beef,bell pepper,cheese tortell...
#
#                                            Recipe Titile  \
# Sno
# 20001  Moroccan Style Beef Wraps (21 Day Wonder Diet:...
# 20002                            Crock Pot Welsh Rarebit
# 20003                                       Easy Brisket
# 20004                           Garam Masala Spice Blend
# 20005                    Quick  Cheez  Chili Beef  Pasta
#
#                                       Ingredient Phrases  \
# Sno
# 20001   600 g dark turkey meat | 1 1/2 teaspoons curr...
# 20002   6 -8 ounces boneless blade steak | 1/4 cup fr...
# 20003   2 large italian sausage, or other ground beef...
# 20004   1 1/2 teaspoons coriander powder | 1/2 teaspo...
# 20005   1 lb beef | 12 ounces cheese tortellini, unco...
#
#                                      Recipe Instructions
# Sno
# 20001  Cook turkey over medium heat in a medium sauce...
# 20002  Put the first 3 ingredients in the crockpot. T...
# 20003  Preheat oven to 300 degrees f. Place brisket i...
# 20004  Using an electric spice mill grind coriander p...
# 20005  Cut beef into 1 thick slices. Place slices bet...

# %%
df=renameColumns(df)

# %%
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients3.csv')

# %%
df=removeRandomIngredientColumn(df)

# %%
df.head()
# Out:
#                                                    title  \
# Sno
# 20001  Moroccan Style Beef Wraps (21 Day Wonder Diet:...
# 20002                            Crock Pot Welsh Rarebit
# 20003                                       Easy Brisket
# 20004                           Garam Masala Spice Blend
# 20005                    Quick  Cheez  Chili Beef  Pasta
#
#                                              ingredients  \
# Sno
# 20001   600 g dark turkey meat | 1 1/2 teaspoons curr...
# 20002   6 -8 ounces boneless blade steak | 1/4 cup fr...
# 20003   2 large italian sausage, or other ground beef...
# 20004   1 1/2 teaspoons coriander powder | 1/2 teaspo...
# 20005   1 lb beef | 12 ounces cheese tortellini, unco...
#
#                                             instructions
# Sno
# 20001  Cook turkey over medium heat in a medium sauce...
# 20002  Put the first 3 ingredients in the crockpot. T...
# 20003  Preheat oven to 300 degrees f. Place brisket i...
# 20004  Using an electric spice mill grind coriander p...
# 20005  Cut beef into 1 thick slices. Place slices bet...

# %%
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients3.csv')

# %% [markdown]
# **Prepairing 4th batch of 10000 recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Adarsh Results/Adarsh_9_5000_Recipes.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Adarsh Results/Adarsh_10_5000_Recipes.csv')

# %%
df=pd.concat([df1,df2])

# %%
df.head()
# Out:
#    Unnamed: 0                                 Random Ingredients  \
# 0           0                     cream mushroom soup,white miso
# 1           1  asparagus,white pepper,ranch salad dressing,ra...
# 2           2                       parsnip,bok choy,fennel seed
# 3           3  serrano chilies,baking soda,liquid smoke,cauli...
# 4           4  chili garlic sauce,white flour,hoisin sauce,ca...
#
#                            Recipe Titile  \
# 0           Miso Cream Sauce for Seafood
# 1      Asparagus Salad (Ranch Asparagus)
# 2  Bok Choy - Parsnip and Fennel Chowder
# 3                      Smoky Cauliflower
# 4                          Quick Hot Dog
#
#                                   Ingredient Phrases  \
# 0   8 ounces light cream of mushroom soup | 1 oun...
# 1   1 cup chopped fresh asparagus | 1/2 cup thinl...
# 2   1 bunch parsnip | 1 teaspoon fennel seed | 1 ...
# 3   1 head cauliflower | 2 serrano chilies | 2 cu...
# 4   1 lb good quality beef round steak, thinly sl...
#
#                                  Recipe Instructions
# 0   Put 1 oz of cream of mushroom soup into small...
# 1   Toss the asparagus, purple onion, 1 tablespoo...
# 2   Rinse and peel potatoes and cut into 1/2 inch...
# 3   Steam the cauliflower until the leaves are se...
# 4   Mix hoisin sauce, flour, tomatoes, green chil...

# %%
df=removeUnnamed0Column(df)

# %%
df.head()
# Out:
#                                   Random Ingredients  \
# 0                     cream mushroom soup,white miso
# 1  asparagus,white pepper,ranch salad dressing,ra...
# 2                       parsnip,bok choy,fennel seed
# 3  serrano chilies,baking soda,liquid smoke,cauli...
# 4  chili garlic sauce,white flour,hoisin sauce,ca...
#
#                            Recipe Titile  \
# 0           Miso Cream Sauce for Seafood
# 1      Asparagus Salad (Ranch Asparagus)
# 2  Bok Choy - Parsnip and Fennel Chowder
# 3                      Smoky Cauliflower
# 4                          Quick Hot Dog
#
#                                   Ingredient Phrases  \
# 0   8 ounces light cream of mushroom soup | 1 oun...
# 1   1 cup chopped fresh asparagus | 1/2 cup thinl...
# 2   1 bunch parsnip | 1 teaspoon fennel seed | 1 ...
# 3   1 head cauliflower | 2 serrano chilies | 2 cu...
# 4   1 lb good quality beef round steak, thinly sl...
#
#                                  Recipe Instructions
# 0   Put 1 oz of cream of mushroom soup into small...
# 1   Toss the asparagus, purple onion, 1 tablespoo...
# 2   Rinse and peel potatoes and cut into 1/2 inch...
# 3   Steam the cauliflower until the leaves are se...
# 4   Mix hoisin sauce, flour, tomatoes, green chil...

# %%
df=removeSpacesFromRecipeInstructions(df)

# %%
df=assignRecipeIds(df,30000)

# %%
df.head()
# Out:
#                                       Random Ingredients  \
# Sno
# 30001                     cream mushroom soup,white miso
# 30002  asparagus,white pepper,ranch salad dressing,ra...
# 30003                       parsnip,bok choy,fennel seed
# 30004  serrano chilies,baking soda,liquid smoke,cauli...
# 30005  chili garlic sauce,white flour,hoisin sauce,ca...
#
#                                Recipe Titile  \
# Sno
# 30001           Miso Cream Sauce for Seafood
# 30002      Asparagus Salad (Ranch Asparagus)
# 30003  Bok Choy - Parsnip and Fennel Chowder
# 30004                      Smoky Cauliflower
# 30005                          Quick Hot Dog
#
#                                       Ingredient Phrases  \
# Sno
# 30001   8 ounces light cream of mushroom soup | 1 oun...
# 30002   1 cup chopped fresh asparagus | 1/2 cup thinl...
# 30003   1 bunch parsnip | 1 teaspoon fennel seed | 1 ...
# 30004   1 head cauliflower | 2 serrano chilies | 2 cu...
# 30005   1 lb good quality beef round steak, thinly sl...
#
#                                      Recipe Instructions
# Sno
# 30001  Put 1 oz of cream of mushroom soup into small ...
# 30002  Toss the asparagus, purple onion, 1 tablespoon...
# 30003  Rinse and peel potatoes and cut into 1/2 inch ...
# 30004  Steam the cauliflower until the leaves are sep...
# 30005  Mix hoisin sauce, flour, tomatoes, green chile...

# %%
df=renameColumns(df)

# %%
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients4.csv')

# %%
df=removeRandomIngredientColumn(df)

# %%
df.head()
# Out:
#                                        title  \
# Sno
# 30001           Miso Cream Sauce for Seafood
# 30002      Asparagus Salad (Ranch Asparagus)
# 30003  Bok Choy - Parsnip and Fennel Chowder
# 30004                      Smoky Cauliflower
# 30005                          Quick Hot Dog
#
#                                              ingredients  \
# Sno
# 30001   8 ounces light cream of mushroom soup | 1 oun...
# 30002   1 cup chopped fresh asparagus | 1/2 cup thinl...
# 30003   1 bunch parsnip | 1 teaspoon fennel seed | 1 ...
# 30004   1 head cauliflower | 2 serrano chilies | 2 cu...
# 30005   1 lb good quality beef round steak, thinly sl...
#
#                                             instructions
# Sno
# 30001  Put 1 oz of cream of mushroom soup into small ...
# 30002  Toss the asparagus, purple onion, 1 tablespoon...
# 30003  Rinse and peel potatoes and cut into 1/2 inch ...
# 30004  Steam the cauliflower until the leaves are sep...
# 30005  Mix hoisin sauce, flour, tomatoes, green chile...

# %%
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients4.csv')

# %% [markdown]
# **Prepairing 5th batch of 10000 recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_6.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_7.csv')
df3=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_6_3000_Recipes.csv')

# %%
df=pd.concat([df1,df2,df3])

# %%
df.head()
# Out:
#    Unnamed: 0                                 Random Ingredients  \
# 0           0  kalamata olive,onion soup mix,romaine lettuce ...
# 1           1  wasabi paste,ancho chile powder,ginger,seasoni...
# 2           2  chili paste,mace,mexican cheese,apple juice,wh...
# 3           3                         coconut milk,green chilies
# 4           4  chicken wing,scallion,seasoning salt,guacamole...
#
#                                        Recipe Titile  \
# 0             Korean Beef and Shiitake Lettuce Wraps
# 1                       Wasabi-Glazed Fried Potatoes
# 2                 Applejack "Pierce" Beef Sandwiches
# 3                      Green Chilies in Coconut Milk
# 4  Quick  Tex Mex  Chili Wings  With  Spicy  Goya...
#
#                                   Ingredient Phrases  \
# 0   1 cup plain yogurt | 1/4 cup grated miniature...
# 1   3 russet potatoes, quartered | 1 tablespoon s...
# 2   2 lbs rump roast or 2 lbs top round beef | 2 ...
# 3   15 1/2 ounces coconut milk | 1 3/4 ounces gre...
# 4   1 1/2 lbs chicken wings | 1 can chickpeas, wi...
#
#                                  Recipe Instructions  Unnamed: 0.1
# 0   In a bowl, stir together the yogurt, chocolat...           NaN
# 1   Preheat oven to 400 degrees f. Lightly grease...           NaN
# 2                      Cover roast with water.\n\n\n           NaN
# 3   Combine all ingredients in a pot, and simmer ...           NaN
# 4   Rinse and drain the chicken wings. Remove all...           NaN

# %%
df=removeUnnamed0Column(df)
df=removeUnnamed01Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,40000)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients5.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients5.csv')

# %% [markdown]
# **Prepairing 6th batch of 10000 recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_7_3000_Recipes.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/3500_Parul_9.csv')
df3=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_9.csv')

# %%
df=pd.concat([df1,df2,df3])

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0           0.0
# 1           1           1.0
# 2           2           2.0
# 3           3           3.0
# 4           4           4.0
#
#                                   Random Ingredients  \
# 0  sushi rice,stew meat,hard egg,currant,basil,gr...
# 1                           sesame seed,almond paste
# 2                                           date,oil
# 3  lasagna noodle,caper,chili oil,sharp cheddar c...
# 4  granny smith apple,white pearl onion,white flo...
#
#                     Recipe Titile  \
# 0        Korean Beef and Egg Roll
# 1       Sesame Paste... or Spread
# 2              Kuwaiti Date Balls
# 3    Cheese and Chili Oil Lasagna
# 4  Quick Italian White Applesauce
#
#                                   Ingredient Phrases  \
# 0   36 ladyfingers | 1 lb sirloin stew meat or 1 ...
# 1   6 -8 tablespoons almond paste | 1 tablespoon ...
# 2         50 dates | 3 tablespoons oil | 500 ml oil
# 3   32 ounces rotelle pasta | 1/2 lb sharp chedda...
# 4   5 large italian-style peeled white pearl onio...
#
#                                  Recipe Instructions
# 0   Make the sticky rice, in a large skillet set ...
# 1   Mix, store in airtight container or in the re...
# 2   Put dates in a blender, add oil, stir, grind ...
# 3   Cook pasta in boiling water. Meanwhile, in a ...
# 4   Place the pearl onions into a medium saucepan...

# %%
df.shape
# Out:
# (10000, 6)

# %%
df=removeUnnamed0Column(df)
df=removeUnnamed01Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,50000)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients6.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients6.csv')

# %% [markdown]
# **Prepairing 7th batch of 10000 recipes**

# %%
df=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Adarsh Results/Adarsh_11_10000_Recipes.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                 Random Ingredients  \
# 0           0      chili pepper,chicken breast half,garlic paste
# 1           1  poultry seasoning,seashell pasta,chicken bouil...
# 2           2  curry powder,ladyfinger,penne pasta,chocolate,...
# 3           3                                  milk,garlic clove
# 4           4  ginger garlic paste,heavy cream,red chilies,ga...
#
#                              Recipe Titile  \
# 0                                    Korma
# 1                  Crock Pot Easiest Broth
# 2          Caramelized Grilled Pasta Salad
# 3                    Brazilian Garlic Soup
# 4  The Ultimate White Sauce for Vegetables
#
#                                   Ingredient Phrases  \
# 0   1 tablespoon garlic paste | 4 boneless chicke...
# 1   2 bags seashell pasta | 1 chicken bouillon cu...
# 2   3 ounces uncooked penne pasta | 2 1/4 cups bu...
# 3   4 garlic cloves, minced | 1 can sweetened con...
# 4   2 1/2 ounces fresh red chilies, chopped | 3/4...
#
#                                  Recipe Instructions
# 0   Cook 1 tablespoon garlic paste in a non stick...
# 1   Pour in the chicken bouillon cube.  Place und...
# 2   Cook pasta as directed on package.  Reserve 1...
# 3   Mince the garlic and combine it with the cond...
# 4   Combine all the ingredients in a food process...

# %%
df.shape
# Out:
# (10000, 5)

# %%
df=removeUnnamed0Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,60000)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients7.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients7.csv')

# %% [markdown]
# **Prepairing 8th batch of 10000 recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/1500_Niharika_8.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_10.csv')
df3=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_8.1_2000_Recipes.csv')
df4=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_10.1_3000_Recipes.csv')

# %%
df=pd.concat([df1,df2,df3,df4])

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.head()
# Out:
#    Unnamed: 0                                 Random Ingredients  \
# 0           0                  chocolate square,cumin,white tuna
# 1           1                          pepperoni,breadcrumb,beer
# 2           2  phyllo dough,garlic powder,catsup,red pepper f...
# 3           3               green bean,marmalade,romaine lettuce
# 4           4        cream chicken soup,chipotle chile,tap water
#
#                                    Recipe Titile  \
# 0               Tuna and Chocolate Balls - Spain
# 1                      Coney-Pimiento Beer Bread
# 2  Bacon Wrapped Eggplant (Russian Pepperoncini)
# 3                Green Beans and Marmalade Salad
# 4                    Quick  Mexican Cream  Soup
#
#                                   Ingredient Phrases  \
# 0   1/2 cup white tuna, cooked and drained | 2 un...
# 1   8 ounces breadcrumbs | 1/4 lb pepperoni | 14 ...
# 2   1 large eggplant, diced small | 1 can french ...
# 3   1 pound fresh green beans | 1/2 cup marmalade...
# 4   1 can cream of chicken soup ( campbell's bran...
#
#                                  Recipe Instructions  Unnamed: 0.1
# 0   In a large bowl, stir together tuna, chocolat...           NaN
# 1   In a large bowl, combine bread crumbs and pep...           NaN
# 2   Cook eggplant until tender on the outside and...           NaN
# 3   Cut ends off each green bean and snap the end...           NaN
# 4   Combine all ingredients until smooth. Serve w...           NaN

# %%
df=removeUnnamed0Column(df)
df=removeUnnamed01Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,70000)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients8.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients8.csv')

# %% [markdown]
# **Prepairing 9th batch of 10000 recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_11.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_12.csv')
df3=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_11.1_3000_Recipes.csv')

# %%
df=pd.concat([df1,df2,df3])

# %%
df.head()
# Out:
#    Unnamed: 0                                 Random Ingredients  \
# 0           0          palm sugar,chocolate,wasabi,cider vinegar
# 1           1  turmeric powder,anaheim chili,tomato sauce,bak...
# 2           2  peach,rigatoni pasta,hazelnut,cremini mushroom...
# 3           3                               almond extract,bacon
# 4           4  grand marnier,salmon,creamy goat cheese,tamari...
#
#                                     Recipe Titile  \
# 0                                    Wasabi Chaat
# 1  Crock Pot Chili (Cooking, Microwave & Low Fat)
# 2               Apple and Hazelnut Rigatoni Salad
# 3                                   Almond Crisps
# 4    Quick  Greek Salmon  With  Whole Grain Cream
#
#                                   Ingredient Phrases  \
# 0   1 cup good quality chocolate ( bittersweet is...
# 1   2 medium baking potatoes, scrubbed | 2 cans t...
# 2   3/4 cup smooth peanut butter | 2/3 cup packed...
# 3        1/2 lb bacon | 1/2 teaspoon almond extract
# 4   1 lb fresh salmon ( skinned, bones removed, s...
#
#                                  Recipe Instructions  Unnamed: 0.1
# 0   The measurements are approximate and the prop...           NaN
# 1   Spray crock pot with non stick spray. In smal...           NaN
# 2   In a small bowl, cream together peanut butter...           NaN
# 3   Preheat oven to 375 degrees f. Line a cookie ...           NaN
# 4   Mix yogurt and cream cheese in a large bowl t...           NaN

# %%
df=removeUnnamed0Column(df)
df=removeUnnamed01Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,80000)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients9.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients9.csv')

# %% [markdown]
# **Prepairing 10th batch of 10000 recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/3500_Parul_12.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/3500_Parul_13.csv')
df3=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_10.2_500_Recipes.csv')
df4=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_11.2_500_Recipes.csv')
df5=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/Parul_8.2_1000_Recipes.csv')
df6=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/1000_Niharika_13.3.csv')

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6])

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.head()
# Out:
#    Unnamed: 0                                 Random Ingredients  \
# 0           0  macaroni,breadcrumb,maple syrup,double cream,o...
# 1           1                             vegetable,salsa,cashew
# 2           2  escarole,red bell pepper,chicken leg,salt seas...
# 3           3                              grain rice,lemon zest
# 4           4  escarole,black mustard seed,dark corn syrup,mo...
#
#                       Recipe Titile  \
# 0  Curry Mac and Beef With Pastrami
# 1                 Creamy Cashew Dip
# 2      Baking Green Beans & Chicken
# 3                  Lemon Rice Pilaf
# 4                  Clams & Broccoli
#
#                                   Ingredient Phrases  \
# 0   200 g macaroni | 1 teaspoon cornstarch | 100 ...
# 1   6 -8 cups of chopped assorted raw nuts | 24 o...
# 2   2 packages dried escarole | 1 head green chil...
# 3   1 cup light or regular long-grain rice, washe...
# 4   3 lbs escarole ( fresh or frozen ) | 1 head b...
#
#                                  Recipe Instructions  Unnamed: 0.1
# 0   Boil water and add the macaroni. Remove shell...           NaN
# 1   In large bowl, mix all ingredients in microwa...           NaN
# 2   Soak escarole in large pot of water 2 hours u...           NaN
# 3   Place rice in a bowl, season with salt to tas...           NaN
# 4   Combine all ingredients in medium size saucep...           NaN

# %%
df=removeUnnamed0Column(df)
df=removeUnnamed01Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,90000)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithRandomIngredients10.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10000RecipesWithoutRandomIngredients10.csv')

# %% [markdown]
# **Prepairing 11th batch containing 9.5k recipes**

# %%
df1=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/2000_Niharika_13.2.csv')
df2=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/3500_Niharika_14.csv')
df3=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Niharika Results/500_Niharika_13.1.csv')
df4=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Parul Results/3500_Parul_14.csv')

# %%
df=pd.concat([df1,df2,df3,df4])

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0         500         500.0
# 1         501         501.0
# 2         502         502.0
# 3         503         503.0
# 4         504         504.0
#
#                                   Random Ingredients  \
# 0  chili pepper flake,green,bay leaf,pork fillet,...
# 1  caper,parsley,sauerkraut,orange peel,margarine...
# 2                       seasoning mix,stilton cheese
# 3  salsa,tarragon vinegar,macadamia nut,chicken m...
# 4                            tortilla,barbecue sauce
#
#                                    Recipe Titile  \
# 0                                Korean Beef Pie
# 1                     Gourmet Sauerkraut Filling
# 2                          Stilton Cheese Spread
# 3  Brazilian Haystacks (Macadamia Nut and Bacon)
# 4                          Way Too Easy Burritos
#
#                                   Ingredient Phrases  \
# 0   2 tablespoons black pickled chili pepper flak...
# 1   12 slices mini hamburger buns, cut in half | ...
# 2   1 package stilton cheese | 1 package seasonin...
# 3   2 tablespoons chocopher chips | 2 tablespoons...
# 4   3/4 cup barbecue sauce, your favourite flavor...
#
#                                  Recipe Instructions
# 0   In a shallow dish, whisk 1/2 cup water with t...
# 1   Melt margarine in large skillet. Add drained ...
# 2   Cut Stilton into cubes. Blend mixture and sto...
# 3   Place the chocadamias on a plate and place on...
# 4   Spread your favourite bbq sauce on both sides...

# %%
df.shape
# Out:
# (9500, 6)

# %%
df=removeUnnamed0Column(df)
df=removeUnnamed01Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,100000)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/9500RecipesWithRandomIngredientsBatch11.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/9500RecipesWithoutRandomIngredientsBatch11.csv')

# %%
df.tail()
# Out:
#                                         title  \
# Sno
# 109496               Quick Philly Cheesesteak
# 109497              Tortilla & Chickpea Salad
# 109498  Pesto Swiss Rolled-up Pork Tenderloin
# 109499                 Mashed Potato Balls II
# 109500          Beef and Rotini Tostadas #RSC
#
#                                               ingredients  \
# Sno
# 109496   1 pound ground beef bouillon | 6 ounces dried...
# 109497   12 tortillas ( fresh, frozen or previously re...
# 109498   4 slices lean pork tenderloin | 2/3 cup nonfa...
# 109499   2 pounds red potatoes, cubed | 3 hard-cooked ...
# 109500   1 lb rib eye steak | 1 cup sliced spanish oni...
#
#                                              instructions
# Sno
# 109496  Heat a large skillet over medium heat. Cook an...
# 109497  Tortillas, preheat a grill pan to medium. Tear...
# 109498  Mix pesto with grated cheese and orange blosso...
# 109499  Place potatoes into a saucepan with enough wat...
# 109500  Preheat oven to 500°f. Cut steak into thin str...

# %% [markdown]
# **Prepairing 12th(Final) batch containing 10.5k recipes**

# %%
df=pd.read_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Adarsh Results/Adarsh_12_10500_Recipes.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                 Random Ingredients  \
# 0           0  white sugar,chicken breast,cinnamon raisin bre...
# 1           1              stock,rye bread,oyster sauce,cucumber
# 2           2  fennel seed,fennel bulb,chili garlic sauce,oni...
# 3           3  lasagna noodle,orange zest,amarula cream lique...
# 4           4  red wine vinegar,cashew,wesson oil,red curry p...
#
#                        Recipe Titile  \
# 0       Kathleen's Wild Rice Chicken
# 1            Cucumber and Corned Rye
# 2  Quick and Easy Parsnips and Chips
# 3             Amarula Cream Pastries
# 4                Quick Gnocchi Salad
#
#                                   Ingredient Phrases  \
# 0   8 chicken breasts | 1 loaf cinnamon raisin br...
# 1   2 cucumbers | 300 ml stock | 2 tablespoons oy...
# 2   3 parsnips | 1 tablespoon fennel seed | 1 tea...
# 3   15 sheets frozen phyllo pastry | 1 3/4 cups a...
# 4   1 lb uncooked rotisserie-cooked chicken, torn...
#
#                                  Recipe Instructions
# 0   Preheat the oven to 350 degrees f.  Arrange t...
# 1   Cut the rye bread in half, hollow out if nece...
# 2   Preheat oven to 400 degrees f.  Line a baking...
# 3   Remove any loose sheets of phyllo pastry.  Us...
# 4   Toss chicken with seasonings in a large bowl....

# %%
df.shape
# Out:
# (10500, 5)

# %%
df=removeUnnamed0Column(df)
df=removeSpacesFromRecipeInstructions(df)
df=assignRecipeIds(df,109500)
df=renameColumns(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10500RecipesWithRandomIngredientsBatch12.csv')
df=removeRandomIngredientColumn(df)
df.to_csv('/content/drive/MyDrive/Monsoon22_conditional_recipe_gen/Recipe Result/Merged Recipes/10500RecipesWithoutRandomIngredientsBatch12.csv')

# %%
df.tail()
# Out:
#                                                     title  \
# Sno
# 119996               Ham, Pineapple and Green Onion Salad
# 119997                         Pan Seared Beef Tenderloin
# 119998  Jalepeno Peppers and Chocolate (Jalapeno Nibbles)
# 119999                             Southern Style Chicken
# 120000                       Apricot-Glazed Bean Sandwich
#
#                                               ingredients  \
# Sno
# 119996   3/4 pound fresh ham, cut into matchsticks ( o...
# 119997   1 1/2 lbs beef tenderloin, 1 cut into 12 equa...
# 119998   2 large jalapeno peppers | salt & freshly gro...
# 119999   4 skinless, boneless chicken breast halves | ...
# 120000   1 can cannellini beans, rinsed and drained | ...
#
#                                              instructions
# Sno
# 119996  Place ham in a medium skillet.  Pour pineapple...
# 119997  Preheat grill to medium heat and lightly oil a...
# 119998  Wash, slit, and deseed the peppers.  You can a...
# 119999  Season the chicken breasts with the seasoning ...
# 120000  Preheat oven to 325 degrees f.  Combine the be...

# %% [markdown]
# **Therefore, Total We have delivered 120k Novel Recipes ✅**
